# %%
import pandas as pd

# %%
score_df = pd.DataFrame([[1,50,80,70,'boy',1],[2,60,45,50,'boy',2],[3,98,43,55,'boy',1],[4,70,69,89,'boy',2],[5,56,79,60,'girl',1],[6,60,68,55,'girl',2],[7,45,70,77,'girl',1],[8,55,77,76,'girl',2],[9,25,57,60,'girl',1],[10,88,40,43,'girl',3],[11,25,60,45,'boy',3],[12,80,60,23,'boy',3],[13,20,90,66,'girl',3],[14,50,50,50,'girl',3],[15,89,67,77,'girl',3]],columns=['student_id','math_score','english_score','chinese_score','sex','class'])
score_df
# Out:
#     student_id  math_score  english_score  chinese_score   sex  class
# 0            1          50             80             70   boy      1
# 1            2          60             45             50   boy      2
# 2            3          98             43             55   boy      1
# 3            4          70             69             89   boy      2
# 4            5          56             79             60  girl      1
# 5            6          60             68             55  girl      2
# 6            7          45             70             77  girl      1
# 7            8          55             77             76  girl      2
# 8            9          25             57             60  girl      1
# 9           10          88             40             43  girl      3
# 10          11          25             60             45   boy      3
# 11          12          80             60             23   boy      3
# ...

# %%
#找出全年級各科成績最高分與最低分？
score_df.loc[:,['math_score','english_score','chinese_score','class']].groupby('class').agg(['max','min'])
# Out:
#       math_score     english_score     chinese_score
#              max min           max min           max min
# class
# 1             98  25            80  43            77  55
# 2             70  55            77  45            89  50
# 3             89  20            90  40            77  23

# %%
#找出數學班平均最高的班級？
score_df.loc[:,['math_score','class']].groupby('class').agg('mean')
# Out:
#        math_score
# class
# 1       54.800000
# 2       61.250000
# 3       58.666667

# %%
#分析全校女生與男生國文平均差幾分？
chinesegap = score_df.loc[:,['chinese_score', 'sex']].groupby('sex').agg('mean')
chinesegap
# Out:
#       chinese_score
# sex
# boy       55.333333
# girl      62.666667

# %%
abs(chinesegap.iloc[0]-chinesegap.iloc[1])
# Out:
# chinese_score    7.333333
# dtype: float64
